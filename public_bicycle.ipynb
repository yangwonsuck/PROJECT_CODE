# %%
import pandas as pd
import numpy as np
df=pd.read_csv('data.csv') 
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.shape # 데이터 건수 10886건,컬럼수 12건
# Out:
# (10886, 12)

# %%
df.describe() #통계 항목 조회
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.info() #데이터 유형 조회
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.head(20) # 20개 데이터의 세부 내용 조회
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5   2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6   2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7   2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8   2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9   2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 10  2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# ...

# %%
df['temp'].describe() # 기온 데이터 조회
# Out:
# count    10886.00000
# mean        20.23086
# std          7.79159
# min          0.82000
# 25%         13.94000
# 50%         20.50000
# 75%         26.24000
# max         41.00000
# Name: temp, dtype: float64

# %%
df.isnull().sum() #null 값이 있는지 조회
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
df['datetime']=df['datetime'].str.replace(pat=' ',repl='-') # hourly date 와 timestamp 사이의 빈칸을 -로 대체
df['datetime']=df['datetime'].str.replace(pat=':',repl='-') # timestamp의 :구분자를 -로 대체
df['datetime'].str.split('-') #yyyy-MM-dd-hh-mm -ss를 나누는 구분자인 -를 기준으로 분리
# Out:
# 0        [2011, 01, 01, 00, 00, 00]
# 1        [2011, 01, 01, 01, 00, 00]
# 2        [2011, 01, 01, 02, 00, 00]
# 3        [2011, 01, 01, 03, 00, 00]
# 4        [2011, 01, 01, 04, 00, 00]
#                     ...
# 10881    [2012, 12, 19, 19, 00, 00]
# 10882    [2012, 12, 19, 20, 00, 00]
# 10883    [2012, 12, 19, 21, 00, 00]
# 10884    [2012, 12, 19, 22, 00, 00]
# 10885    [2012, 12, 19, 23, 00, 00]
# Name: datetime, Length: 10886, dtype: object

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01-00-00-00       1        0           0        1  9.84  14.395
# 1  2011-01-01-01-00-00       1        0           0        1  9.02  13.635
# 2  2011-01-01-02-00-00       1        0           0        1  9.02  13.635
# 3  2011-01-01-03-00-00       1        0           0        1  9.84  14.395
# 4  2011-01-01-04-00-00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
import datetime # 날짜를 추출하기 위한 라이브러리 선언
df['year']=pd.DatetimeIndex(df['datetime']).year  #연도를 따로 뽑아냄 
df['month']=pd.DatetimeIndex(df['datetime']).month #월을 따로 뽑아냄
df['day']=pd.DatetimeIndex(df['datetime']).day #날짜를 따로 뽑아냄
df['hour']=pd.DatetimeIndex(df['datetime']).hour #시간을 따로 뽑아냄
df['minute']=pd.DatetimeIndex(df['datetime']).minute #분을 따로 뽑아냄
df['second']=pd.DatetimeIndex(df['datetime']).second #초를 따로 뽑아냄
df['dayofweek']=pd.DatetimeIndex(df['datetime']).dayofweek #요일을 따로 뽑아냄

# %%
df.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19-19-00-00       4        0           1        1  15.58
# 10882  2012-12-19-20-00-00       4        0           1        1  14.76
# 10883  2012-12-19-21-00-00       4        0           1        1  13.94
# 10884  2012-12-19-22-00-00       4        0           1        1  13.94
# 10885  2012-12-19-23-00-00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# 10881  19.695        50    26.0027       7         329    336  2012     12
# 10882  17.425        57    15.0013      10         231    241  2012     12
# 10883  15.910        61    15.0013       4         164    168  2012     12
# 10884  17.425        61     6.0032      12         117    129  2012     12
# 10885  16.665        66     8.9981       4          84     88  2012     12
#
#        day  hour  minute  second  dayofweek
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,7))
plt.subplot(2,3,1)
plt.title('year')
plt.plot(df['year'],df['count']) #연도와 대여수를 시각화 -> 2011초반과 2012년 초반이 대여수가 급등함
plt.subplot(2,3,2)
plt.title('month')
plt.plot(df['month'],df['count'],'r') #달과 대여수를 시각화 ->여름에서 가을 사이가 대여수가 많음
plt.subplot(2,3,3)
plt.title('day')
plt.plot(df['day'],df['count'],'b') #일자와 대여수를 시각화 
plt.subplot(2,3,4)
plt.title('hour')
plt.plot(df['hour'],df['count'],'g') #시간과 대여수를 시각화 ->오전 7~8시와 12~13시 17~18 시 사이가 대여수가 많음
plt.subplot(2,3,5)
plt.title('minute')
plt.plot(df['minute'],df['count']) #분과 대여수를 시각화
plt.subplot(2,3,6)
plt.title('second') 
plt.plot(df['second'],df['count']) #초와 대여수를 시각화
plt.show()
# Out:
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# ...

# %%
#전체 대여량, 계절별 대여량, 시간별 대여량, 근무일에 따른 대여량

plt.figure(figsize=(20,7))
plt.subplot(2,3,1)
plt.title('total_count')
plt.plot(df['count']) #전체대여수를 시각화 -> 점점 늘어나게 됨

plt.subplot(2,3,2)
plt.title('season')
plt.plot(df['season'],df['count'],'r') #계절과 대여수를 시각화 -> 여름과 가을에 대여수가 급등함

plt.subplot(2,3,3)
plt.title('hour')
plt.plot(df['hour'],df['count'],'g') #시간과 대여수를 시각화 ->오전 7~8시와 12~13시 17~18 시 사이가 대여수가 많음

plt.subplot(2,3,4)
plt.title('workingday')
plt.plot(df['workingday'],df['count'],'b') #일하는 날과대여수를 시각화 -> 일을 하는 날이 대여수가 더 많음
# Out:
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# ...

# %%
df_time=df[['year','month','day','hour','minute','second','dayofweek']]
df_time
# Out:
#        year  month  day  hour  minute  second  dayofweek
# 0      2011      1    1     0       0       0          5
# 1      2011      1    1     1       0       0          5
# 2      2011      1    1     2       0       0          5
# 3      2011      1    1     3       0       0          5
# 4      2011      1    1     4       0       0          5
# ...     ...    ...  ...   ...     ...     ...        ...
# 10881  2012     12   19    19       0       0          2
# 10882  2012     12   19    20       0       0          2
# 10883  2012     12   19    21       0       0          2
# 10884  2012     12   19    22       0       0          2
# 10885  2012     12   19    23       0       0          2
#
# [10886 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#시간대별 대여량
plt.figure(figsize=(20,7))
plt.subplot(2,3,1)
plt.title('hour per count')
plt.plot(df['hour'],df['count'],'g') #시간과 대여수를 시각화 ->오전 7~8시와 12~13시 17~18 시 사이가 대여수가 많음
#시간대별(근무일,휴일) 대여량
plt.subplot(2,3,2)
plt.title('workingday per count')
plt.plot(df['workingday'],df['count'],'b') #일하는날과 대여수를 시각화 ->일하는 날일때가  대여수가 많음
plt.subplot(2,3,3)
plt.title('holiday per count')
plt.plot(df['holiday'],df['count'],'r')  #휴일과 대여수를 시각화 ->일하는 날일때가  대여수가 많음
# Out:
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#요일별 대여량
plt.figure(figsize=(20,7))
plt.subplot(2,4,1)
plt.title('monday per count')
plt.plot(df['dayofweek']==0,df['count'],'g') #월요일과 대여수를 시각화 

plt.subplot(2,4,2)
plt.title('tuesday per count')
plt.plot(df['dayofweek']==1,df['count'],'b') #화요일과 대여수를 시각화 

plt.subplot(2,4,3)
plt.title('wed per count')
plt.plot(df['dayofweek']==2,df['count'],'r')  #수요일과 대여수를 시각화

plt.subplot(2,4,4) 
plt.title('thur per count')
plt.plot(df['dayofweek']==3,df['count'],'g')  #목요일과 대여수를 시각화

plt.subplot(2,4,5)
plt.title('fri per count')
plt.plot(df['dayofweek']==4,df['count'],'b')  #금요일과 대여수를 시각화

plt.subplot(2,4,6)
plt.title('sat per count')
plt.plot(df['dayofweek']==5,df['count'],'r')  #토요일과 대여수를 시각화

plt.subplot(2,4,7)
plt.title('sun per count')
plt.plot(df['dayofweek']==6,df['count'],'g')  #일요일과 대여수를 시각화
# Out:
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# Exception ignored in: <_io.BufferedReader name='/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'>
# OSError: [Errno 116] Stale file handle
# ...

# %%
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18, 8)

sns.barplot(data=df, x="year", y="count", ax=ax1)
sns.barplot(data=df, x="month", y="count", ax=ax2)
sns.barplot(data=df, x="day", y="count", ax=ax3)
sns.barplot(data=df, x="hour", y="count", ax=ax4)
sns.barplot(data=df, x="minute", y="count", ax=ax5)
sns.barplot(data=df, x="second", y="count", ax=ax6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-5060cee6054f> in <module>
#       9 figure.set_size_inches(18, 8)
#      10
# ---> 11 sns.barplot(data=df, x="year", y="count", ax=ax1)
#      12 sns.barplot(data=df, x="month", y="count", ax=ax2)
#      13 sns.barplot(data=df, x="day", y="count", ax=ax3)
#
# /opt/app-root/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/app-root/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
# ...
